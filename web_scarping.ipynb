# %% [markdown]
# <a href="https://colab.research.google.com/github/devanshu3/Web-Scraping/blob/main/web_scarping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
Name=[]
Ratings=[]
Genre=[]
Year=[]

# %%
url = "https://www.imdb.com/search/title/?title_type=tv_series&num_votes=100000,&sort=release_date,asc"
content = requests.get(url).content

# %%
soup = BeautifulSoup(content,"html.parser")

for a in soup.findAll('div', attrs={'class':'lister-item mode-advanced'}):
    h = a.find('h3', attrs={'class':'lister-item-header'})
    a_Name=h.find('a', href=True)
    a_Rating=a.find('div', attrs={'class':'inline-block ratings-imdb-rating'})
    a_Genre=a.find('span', attrs={'class':'genre'})
    a_Year=a.find('span', attrs={'class':'lister-item-year text-muted unbold'})
    Name.append(a_Name.text)
    Ratings.append(a_Rating.text.strip("\n"))
    Genre.append(a_Genre.text.strip("\n"))
    Year.append(a_Year.text)

# %%
df= pd.DataFrame({'Series Name':Name,'Release Year':Year,'Ratings':Ratings,'Genre':Genre})
df.to_csv('/content/18it106-web-scraping.csv', index = False, encoding= 'utf-8-sig')

df
# Out:
#                           Series Name Release Year Ratings  \
# 0               Married with Children  (1987–1997)     8.1
# 1      Star Trek: The Next Generation  (1987–1994)     8.7
# 2                            Seinfeld  (1989–1998)     8.9
# 3                          Twin Peaks  (1990–1991)     8.8
# 4                        The Simpsons     (1989– )     8.7
# 5                       Dragon Ball Z  (1989–1996)     8.8
# 6                            Mr. Bean  (1990–1995)     8.6
# 7         The Fresh Prince of Bel-Air  (1990–1996)     7.9
# 8         Batman: The Animated Series  (1992–1995)     9.0
# 9                         The X Files  (1993–2018)     8.6
# 10                            Friends  (1994–2004)     8.9
# 11           Buffy the Vampire Slayer  (1997–2003)     8.3
# 12                                 Oz  (1997–2003)     8.7
# 13                         South Park     (1997– )     8.7
# 14                     Kaubôi bibappu  (1998–1999)     8.9
# 15                   Sex and the City  (1998–2004)     7.3
# 16                     That '70s Show  (1998–2006)     8.1
# 17                       The Sopranos  (1999–2007)     9.2
# 18                         Family Guy     (1999– )     8.2
# 19                           Futurama     (1999– )     8.5
# 20              SpongeBob SquarePants     (1999– )     8.2
# 21  Law & Order: Special Victims Unit     (1999– )     8.1
# 22                   Freaks and Geeks  (1999–2000)     8.8
# 23                One Piece: Stampede     (1999– )     8.9
# 24              Malcolm in the Middle  (2000–2006)     8.2
# 25                      Gilmore Girls  (2000–2007)     8.2
# 26               Curb Your Enthusiasm     (2000– )     8.8
# 27                         Smallville  (2001–2011)     7.5
# 28                     Six Feet Under  (2001–2005)     8.7
# 29                         The Office  (2001–2003)     8.5
# 30                             Scrubs  (2001–2010)     8.4
# 31                                 24  (2001–2010)     8.4
# 32                           The Wire  (2002–2008)     9.3
# 33                            Firefly  (2002–2003)     9.0
# 34                             Naruto  (2002–2007)     8.4
# 35                           Top Gear     (2002– )     8.7
# 36                               NCIS     (2003– )     7.8
# 37                 Two and a Half Men  (2003–2015)     7.1
# 38               Arrested Development  (2003–2019)     8.7
# 39                           Deadwood  (2004–2006)     8.6
# 40                          Entourage  (2004–2011)     8.4
# 41                               Lost  (2004–2010)     8.3
# 42               Desperate Housewives  (2004–2012)     7.6
# 43               Battlestar Galactica  (2004–2009)     8.7
# 44                         House M.D.  (2004–2012)     8.7
# 45                      American Dad!     (2005– )     7.4
# 46         Avatar: The Last Airbender  (2005–2008)     9.3
# 47                         The Office  (2005–2013)     9.0
# 48                         Doctor Who     (2005– )     8.6
# 49                     Grey's Anatomy     (2005– )     7.6
#
#                                        Genre
# 0                         Comedy
# 1       Action, Adventure, Drama
# 2                         Comedy
# 3          Crime, Drama, Mystery
# 4              Animation, Comedy
# 5   Animation, Action, Adventure
# 6                 Comedy, Family
# 7                         Comedy
# 8   Animation, Action, Adventure
# 9          Crime, Drama, Mystery
# 10               Comedy, Romance
# 11        Action, Drama, Fantasy
# 12        Crime, Drama, Thriller
# 13             Animation, Comedy
# 14  Animation, Action, Adventure
# 15        Comedy, Drama, Romance
# 16        Comedy, Drama, Romance
# 17                  Crime, Drama
# 18             Animation, Comedy
# 19  Animation, Adventure, Comedy
# 20     Animation, Comedy, Family
# 21         Crime, Drama, Mystery
# 22                 Comedy, Drama
# 23  Animation, Action, Adventure
# 24                Comedy, Family
# 25                 Comedy, Drama
# 26                        Comedy
# 27      Action, Adventure, Drama
# 28                 Comedy, Drama
# 29                 Comedy, Drama
# 30                 Comedy, Drama
# 31          Action, Crime, Drama
# 32        Crime, Drama, Thriller
# 33      Adventure, Drama, Sci-Fi
# 34  Animation, Action, Adventure
# 35      Adventure, Comedy, Sport
# 36          Action, Crime, Drama
# 37               Comedy, Romance
# 38                        Comedy
# 39         Crime, Drama, History
# 40                 Comedy, Drama
# 41     Adventure, Drama, Fantasy
# 42        Comedy, Drama, Mystery
# 43      Action, Adventure, Drama
# 44                Drama, Mystery
# 45             Animation, Comedy
# 46  Animation, Action, Adventure
# 47                        Comedy
# 48      Adventure, Drama, Sci-Fi
# 49                Drama, Romance
